# %%
import pandas as pd
import os
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager


driver = webdriver.Chrome(ChromeDriverManager().install())

from selenium.webdriver.support.ui import Select
import pyautogui



action = webdriver.common.action_chains.ActionChains(driver)
driver.get("https://staging-kitchen.enterprise.by.me/")
time.sleep(5)


# NOBILIA_ROOT_ADMIN
# VMHp6oc-T4

# %%
iframe = driver.find_element_by_id('embedded-app-frame')
driver.switch_to.frame(iframe)

time.sleep(2)

driver.find_element_by_xpath('//*[@id="step-design"]').click()

# %%
import  pandas as pd
df = pd.read_excel('DataGathering.xlsx')
products = df['Name'].tolist()
len(products)

# %%
# This remove filler from cabinets

def fillerRemoveFunction():
    filler = driver.find_element_by_name('straight-strip-toggle')
    driver.execute_script("arguments[0].scrollIntoView();", filler)
    time.sleep(1)

    filler.click()

    time.sleep(1)
    Frontpath = driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[1]')
    driver.execute_script("arguments[0].scrollIntoView();", Frontpath)



# This function select the front option to display list of fronts

def selectingFrontOption():
    try:
        driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[3]/div/div/button').click()
    except:
        try:
            driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[4]/div/div/button').click()
        except:
            driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[5]/div/div/button[3]').click()



# This function helps us to change the front of the cabinet and return the prices

def pricingFunction():
    front_list = driver.find_element_by_id(f'mod-product-list')
    prices = []
            
    fronts = front_list.find_elements_by_tag_name("li")

    pricing_groups = ['244 - Speed (Prog 351)',
    '427 - Laser (Prog 615)',
    '453 - Flash ( Prog 648)',
    '165 - Fashion ( Prog 406)',
    '551 - Inline ( Prog 526)',
    '776 - Cascada ( Prog 684)',
    '390 - Castello ( Prog 224)',
    '819 - Lux ( Prog 555)',
    '938 - Artis ( Prog 789)'
    ]

    referencePggroups = [
        'PG1','PG2','PG3','PG4','PG5','PG7','PG8','PG9','Pg10'
    ]

    frontsNameList = []
    
    for front in fronts:
        frontsNameList.append(front.find_elements_by_tag_name('p')[0].text)


    for pg in pricing_groups:
        if pg in frontsNameList:
            for front in fronts:
                    if front.find_elements_by_tag_name("p")[0].text == pg:
                        front.click()
                        time.sleep(4)
                        price = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[1]/div/div[2]/p/span[2]/span/span/span').text
                        prices.append(price)
        else:
            prices.append('No Pricing Group')

    return prices

# This function remove worktop from base cabinet
    
def deletingWorktop():
    try:
        driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[6]/div/div/button[3]').click()
    except:
        try:
             driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[7]/div/div/button[3]').click()
        except:
            try:
                driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[5]/div/div/button[3]').click()
            except:
                driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[4]/div/div/button[3]').click()



# getting final price after removing unwanted spaces and other things

def gettingFinalPrice():
    finalprice = []
    for i in prices:
        for j in i:
            if j!='No price':
                if j!= 'Prix indisponible':
                    if j!= 'Calcul du prix en cours...':
                        a = (j.replace(' €',''))
                        a = a.replace(' ','')
                        # a = float(a.replace(',','.'))
                        # a = (round(a-130.4,2))
                        finalprice.append(str(a).replace('.',','))
                    else:
                        finalprice.append(j)
                else:
                    finalprice.append(j)
            else:
                finalprice.append(j)
    return finalprice



# Collecting pricing for open cabintes

def getPriceForOpenCabinets():

        prices =[]
        price = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[1]/div/div[2]/p/span[2]/span/span/span').text
        prices.append(price)

        prices = [prices[0] for _ in range(9)]

        return prices

# %%
prices = getPriceForOpenCabinets()
prices

# %%
# Main function

prices = []

NotabletogetPrice = []

products = ['UD20','U20']

import copy

for ids in products:
    time.sleep(2)
    searchButton = driver.find_element_by_id('search')
    searchButton.click()

    time.sleep(2)

    driver.find_element_by_xpath('//*[@id="catalogSearchBar-form-input"]').send_keys(ids)
    time.sleep(1)

    driver.find_element_by_xpath('//*[@id="catalogSearchBar-form-button"]/span').click()

    time.sleep(2)



    # driver.find_element_by_id('//*[@id="design-mod-properties-window-wide"]/ul/li[1]/ul/li[1]/button/svg').click()
    try:
        
        productlist = driver.find_element_by_id(f'mod-product-list')
                    
        serachedProducts = productlist.find_elements_by_tag_name("li")

        for prod in serachedProducts:
                # print(front.find_elements_by_tag_name("h3")[0].text)
                a = prod.find_elements_by_tag_name("h3")[0].text
                print(a.split(' '))

                l = [a.replace("\n"," ").split(' ')[0] for a in a.split(' ')]
                # print(l[0])

                c = l[0]

                # break
                name = ids

                if c == ids:
                    prod.click() 

        time.sleep(2)
        driver.find_element_by_xpath('//*[@id="header-filter"]/ul/li[2]').click()
        # cancel Button

        time.sleep(3)
        driver.find_element_by_class_name('icon-action-edit').click()
        # edit button click

        time.sleep(4)

        fillerRemoveFunction()
        # removingfiller


        time.sleep(2)


        deletingWorktop()
        # deleing the worktop


        time.sleep(2)



        selectingFrontOption()
        # selecting the front option


        time.sleep(4)

        price = pricingFunction()
        # geting the prices from the pricing fuction
        
        
        # price = getPriceForOpenCabinets()

        # getting the price for open cabinets

        a = copy.deepcopy(price)
        prices.append(a)
        print(prices)
        price = []

       

        driver.find_element_by_xpath('//*[@id="header-filter"]/ul/li[2]/button').click()
        time.sleep(3)

        # cancel button

        deleteButton = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[2]/article[11]/ul/li[2]/button')
        deleteButton.click() 
        # Delete button

    except:
        NotabletogetPrice.append(ids)
        if len(price)<9:
            price =[]
            for i in range(9):
                price.append('No Price')
        
        if len(price)==9:
            a = copy.deepcopy(price)
            # print(a)
            prices.append(a)

        try:

            driver.find_element_by_xpath('//*[@id="design-edit-panel"]/header/ul/li/button').click()
            time.sleep(2)
            # cancel button

            deleteButton = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[2]/article[11]/ul/li[2]/button')
            deleteButton.click()  

        except:
            try:
                driver.find_element_by_xpath('//*[@id="header-filter"]/ul/li[2]/button').click()
                time.sleep(2)
            except:
                deleteButton = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[2]/article[11]/ul/li[2]/button')
                deleteButton.click()
# Out:
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   searchButton = driver.find_element_by_id('search')
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="catalogSearchBar-form-input"]').send_keys(ids)
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="catalogSearchBar-form-button"]/span').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   productlist = driver.find_element_by_id(f'mod-product-list')
# ['UD20\nMore', 'info']
# ['UD20-X\nMore', 'info']
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:51: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="header-filter"]/ul/li[2]').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:55: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name('icon-action-edit').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   filler = driver.find_element_by_name('straight-strip-toggle')
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   Frontpath = driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[1]')
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:75: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[6]/div/div/button[3]').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:78: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[7]/div/div/button[3]').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[3]/div/div/button').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="design-edit-panel"]/div[2]/div/ul/li[4]/div/div/button').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   front_list = driver.find_element_by_id(f'mod-product-list')
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/3168373735.py:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[1]/div/div[2]/p/span[2]/span/span/span').text
# [['65,02 €', '65,02 €', '65,02 €', '65,02 €', '0,00 €', '65,02 €', '65,02 €', '65,02 €', '65,02 €']]
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:96: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="header-filter"]/ul/li[2]/button').click()
# C:\Users\pjn13\AppData\Local\Temp/ipykernel_17676/288796297.py:101: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   deleteButton = driver.find_element_by_xpath('/html/body/div[3]/main/div/div[2]/article[11]/ul/li[2]/button')
# ['U20\nMore', 'info']
# ['U20-X\nMore', 'info']
# [['65,02 €', '65,02 €', '65,02 €', '65,02 €', '0,00 €', '65,02 €', '65,02 €', '65,02 €', '65,02 €'], ['130,04 €', '130,04 €', '130,04 €', '130,04 €', 'No Pricing Group', '130,04 €', '130,04 €', '130,04 €', '130,04 €']]

# %%
print(len(prices))
print(NotabletogetPrice)
print(len(price))
# Out:
# 2
# []
# 0

# %%
prices

# %%
referencePggroups = [
        'PG1','PG2','PG3','PG4','PG5','PG7','PG8','PG9','Pg10'
    ] 
cabietsForPricing = []
pricingGroupsFinal = []
for i in products:
    pricingGroupsFinal.extend([a for a in referencePggroups])
    for _ in range(9):
        cabietsForPricing.append(i)

# %%
finalprice = gettingFinalPrice()
finalprice
# Out:
# ['141,48',
#  '141,48',
#  '141,48',
#  '141,48',
#  '76,46',
#  '141,48',
#  '141,48',
#  '141,48',
#  '141,48',
#  '206,50',
#  '206,50',
#  '206,50',
#  '206,50',
#  'NoPricinggroup',
#  '206,50',
#  '206,50',
#  '206,50',
#  '206,50']

# %%
print(len(finalprice))
print(len(cabietsForPricing))
print(len(pricingGroupsFinal))
# Out:
# 18
# 18
# 18

# %%
import pandas as pd

df1= pd.DataFrame()

df1['Cabinets'] = cabietsForPricing
df1['PricingGroups'] = pricingGroupsFinal 
df1['Prices'] = finalprice
df1.to_excel('DataGathering1.xlsx', index=False)

# %%
driver.execute_script("document.body.style.zoom='33%'")
